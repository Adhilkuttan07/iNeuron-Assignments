# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix

# %%
df=pd.read_csv("C:\\Users\\HP\\Downloads\\uci-census-income\\adults_train.csv")
test=pd.read_csv("C:\\Users\\HP\\Downloads\\uci-census-income\\adults_test.csv")

# %%
df=df[df['Work Class ']!=' ?']
df=df[df['Occupation']!=' ?']
df=df[df['Native Country']!=' ?']
for i in range(len(df)):
    if df.iloc[i,13] not in [' United-States',' Mexico']:
        df.iloc[i,13]='Other Country'
for i in range(len(df)):
    if df.iloc[i,3] in [' 1st-4th',' Preschool',' 5th-6th',' 10th', ' 12th',' 11th', ' 7th-8th',' 9th']:
        df.iloc[i,3]='12th and below'
for i in range(len(df)):
    if df.iloc[i,1] not in [' Private']:
        df.iloc[i,1]=' Not Private'
for i in range(len(df)):
    if df.iloc[i,5]  in [' Married-spouse-absent',' Separated',' Married-AF-spouse',' Widowed']:
        df.iloc[i,5]=' Other'
for i in range(len(df)):
    if df.iloc[i,6]  in [' Protective-serv',' Armed-Forces',' Priv-house-serv']:
        df.iloc[i,6]=' Servants'

# %%
le1=LabelEncoder()
le2=LabelEncoder()
le3=LabelEncoder()
le4=LabelEncoder()
le5=LabelEncoder()
le6=LabelEncoder()
le7=LabelEncoder()
le8=LabelEncoder()
le9=LabelEncoder()
le10=LabelEncoder()
df['Work Class ']=le1.fit_transform(df['Work Class '])
df['Education']=le2.fit_transform(df['Education'])
df['Marital Status']=le3.fit_transform(df['Marital Status'])
df['Occupation']=le4.fit_transform(df['Occupation'])
df['Education']=le5.fit_transform(df['Education'])
df['Relationship']=le6.fit_transform(df['Relationship'])
df['Race']=le7.fit_transform(df['Race'])
df['Sex']=le8.fit_transform(df['Sex'])
df['Native Country']=le9.fit_transform(df['Native Country'])
df['Income']=le10.fit_transform(df['Income'])

# %%
df.corr()
# Out:
#                      Age  Work Class     fnlwgt  Education  Education num  \
# Age             1.000000    -0.210491 -0.076511  -0.039716       0.043526
# Work Class     -0.210491     1.000000  0.046589   0.058257      -0.165069
# fnlwgt         -0.076511     0.046589  1.000000   0.025333      -0.044992
# Education      -0.039716     0.058257  0.025333   1.000000      -0.568206
# Education num   0.043526    -0.165069 -0.044992  -0.568206       1.000000
# Marital Status -0.254936     0.085511  0.034241   0.063278      -0.073244
# Occupation     -0.012280    -0.008662  0.002277  -0.008044       0.059118
# Relationship   -0.246456     0.087619  0.009298   0.067874      -0.091935
# Race            0.023374     0.003045 -0.023895  -0.022503       0.032805
# Sex             0.081993    -0.066803  0.025362  -0.010982       0.006157
# Capital Gain    0.080154    -0.048185  0.000422  -0.026687       0.124416
# Capital Loss    0.060165    -0.036377 -0.009750  -0.031103       0.079646
# ...

# %%
df=pd.read_csv("C:\\Users\\HP\\Downloads\\uci-census-income\\adults_train.csv")
test=pd.read_csv("C:\\Users\\HP\\Downloads\\uci-census-income\\adults_test.csv")

# %%
df=df[df['Work Class ']!=' ?']
df=df[df['Occupation']!=' ?']
df=df[df['Native Country']!=' ?']
for i in range(len(df)):
    if df.iloc[i,13] not in [' United-States',' Mexico']:
        df.iloc[i,13]='Other Country'
for i in range(len(df)):
    if df.iloc[i,3] in [' 1st-4th',' Preschool',' 5th-6th',' 10th', ' 12th',' 11th', ' 7th-8th',' 9th']:
        df.iloc[i,3]='12th and below'
for i in range(len(df)):
    if df.iloc[i,1] not in [' Private']:
        df.iloc[i,1]=' Not Private'
for i in range(len(df)):
    if df.iloc[i,5]  in [' Married-spouse-absent',' Separated',' Married-AF-spouse',' Widowed']:
        df.iloc[i,5]=' Other'
for i in range(len(df)):
    if df.iloc[i,6]  in [' Protective-serv',' Armed-Forces',' Priv-house-serv']:
        df.iloc[i,6]=' Servants'
test=test[test['Work Class ']!=' ?']
test=test[test['Occupation']!=' ?']
test=test[test['Native Country']!=' ?']
for i in range(len(test)):
    if test.iloc[i,13] not in [' United-States',' Mexico']:
        test.iloc[i,13]='Other Country'
for i in range(len(test)):
    if test.iloc[i,3] in [' 1st-4th',' Preschool',' 5th-6th',' 10th', ' 12th',' 11th', ' 7th-8th',' 9th']:
        test.iloc[i,3]='12th and below'
for i in range(len(test)):
    if test.iloc[i,1] not in [' Private']:
        test.iloc[i,1]=' Not Private'
for i in range(len(test)):
    if test.iloc[i,5]  in [' Married-spouse-absent',' Separated',' Married-AF-spouse',' Widowed']:
        test.iloc[i,5]=' Other'
for i in range(len(test)):
    if test.iloc[i,6]  in [' Protective-serv',' Armed-Forces',' Priv-house-serv']:
        test.iloc[i,6]=' Servants'

# %%
for i in range(len(test)):
    if test.iloc[i,14]==' <=50K.':
            test.iloc[i,14]=' <=50K'
    if test.iloc[i,14]==' >50K.':
            test.iloc[i,14]=' >50K'

# %%
df=df.drop(columns=['fnlwgt','Occupation','Native Country','Race'])
df=pd.get_dummies(data=df,columns=['Work Class ','Education','Marital Status','Relationship','Sex'],drop_first=True)
test=test.dropna(axis=0)
test=test.drop(columns=['fnlwgt','Occupation','Native Country','Race'])
test=pd.get_dummies(data=test,columns=['Work Class ','Education','Marital Status','Relationship','Sex'],drop_first=True)

# %%
le11=LabelEncoder()
df['Income']=le11.fit_transform(df['Income'])

# %%
test['Income']=le11.transform(test['Income'])

# %%
df=df[['Age', 'Education num', 'Capital Gain', 'Capital Loss',
       'Hours Per Week', 'Work Class _ Private',
       'Education_ Assoc-voc', 'Education_ Bachelors', 'Education_ Doctorate',
       'Education_ HS-grad', 'Education_ Masters', 'Education_ Prof-school',
       'Education_ Some-college', 'Education_12th and below',
       'Marital Status_ Married-civ-spouse', 'Marital Status_ Never-married',
       'Marital Status_ Other', 'Relationship_ Not-in-family',
       'Relationship_ Other-relative', 'Relationship_ Own-child',
       'Relationship_ Unmarried', 'Relationship_ Wife', 'Sex_ Male','Income']]

# %%
test=test[['Age', 'Education num', 'Capital Gain', 'Capital Loss',
       'Hours Per Week', 'Work Class _ Private',
       'Education_ Assoc-voc', 'Education_ Bachelors', 'Education_ Doctorate',
       'Education_ HS-grad', 'Education_ Masters', 'Education_ Prof-school',
       'Education_ Some-college', 'Education_12th and below',
       'Marital Status_ Married-civ-spouse', 'Marital Status_ Never-married',
       'Marital Status_ Other', 'Relationship_ Not-in-family',
       'Relationship_ Other-relative', 'Relationship_ Own-child',
       'Relationship_ Unmarried', 'Relationship_ Wife', 'Sex_ Male','Income']]

# %%
Xtrain=df.iloc[:,:-1]
ytrain=df.iloc[:,-1]
Xtest=test.iloc[:,:-1]
ytest=test.iloc[:,-1]

# %%
from xgboost import XGBClassifier

# %%
xgb=XGBClassifier()

# %%
xgb.fit(Xtrain,ytrain)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=0, num_parallel_tree=1, random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
ypred=xgb.predict(Xtest)

# %%
confusion_matrix(ytest,ypred)
# Out:
# array([[2519,  166],
#        [ 334,  535]], dtype=int64)

# %%
accuracy_score(ytest,ypred)
# Out:
# 0.859313449634215
